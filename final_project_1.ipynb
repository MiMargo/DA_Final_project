# %% [markdown]
# # Задание 1

# %% [markdown]
# ### Retention – один из самых важных показателей в компании. Ваша задача – написать функцию, которая будет считать retention игроков (по дням от даты регистрации игрока). Данные лежат в папке shared. Функция должна быть написана на python. В ходе решения можно тестировать работу функции как на полном датасете, так и на части (сэмпле) данных.

# %% [markdown]
# ### Импорт данных

# %%
import pandas as pd
import time
import numpy as np
import datetime

# %%
path_to_file_reg = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-m-mihajlova/shared/problem1-reg_data.csv'
path_to_file_auth = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-m-mihajlova/shared/problem1-auth_data.csv'

# %%
reg_data = pd.read_csv(path_to_file_reg, sep=';')
auth_data = pd.read_csv(path_to_file_auth, sep=';')

# %%
reg_data.head()
# Out:
#       reg_ts  uid
# 0  911382223    1
# 1  932683089    2
# 2  947802447    3
# 3  959523541    4
# 4  969103313    5

# %%
auth_data.head()
# Out:
#      auth_ts  uid
# 0  911382223    1
# 1  932683089    2
# 2  932921206    2
# 3  933393015    2
# 4  933875379    2

# %%
# Проверяем, не является ли столбец reg_ts Unix-временем 
time.gmtime(reg_data.reg_ts[0])
# Out:
# time.struct_time(tm_year=1998, tm_mon=11, tm_mday=18, tm_hour=9, tm_min=43, tm_sec=43, tm_wday=2, tm_yday=322, tm_isdst=0)

# %% [markdown]
# ###### Исходя из названий столбцов делаем вывод, что
# uid - id пользователя;
#
# reg_ts - время регистрации (в формате Unix)
#
# auth_ts - время использования (в формате Unix)

# %% [markdown]
# ### Предварительный анализ

# %%
reg_data.shape
# Out:
# (1000000, 2)

# %%
auth_data.shape
# Out:
# (9601013, 2)

# %%
reg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   reg_ts  1000000 non-null  int64
#  1   uid     1000000 non-null  int64
# dtypes: int64(2)
# memory usage: 15.3 MB

# %%
auth_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9601013 entries, 0 to 9601012
# Data columns (total 2 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   auth_ts  int64
#  1   uid      int64
# dtypes: int64(2)
# memory usage: 146.5 MB

# %%
# Проверка дубликатов
reg_data.duplicated().sum()
# Out:
# 0

# %%
auth_data.duplicated().sum()
# Out:
# 0

# %%
# Проверка наличия пустых значений
reg_data.isna().sum()
# Out:
# reg_ts    0
# uid       0
# dtype: int64

# %%
auth_data.isna().sum()
# Out:
# auth_ts    0
# uid        0
# dtype: int64

# %% [markdown]
# Видим, что в данных нет отсутствующих значений и дубликатов. Тип колонок соответствует содержимому.

# %% [markdown]
# ### Решение

# %% [markdown]
# Retention n-ого дня = количество пользоватей в n-ый день / количество зарегистрированных пользователей

# %% [markdown]
# Для расчета Retention игроков по дням от даты регистрации игрока воспользуемся методом когортного анализа.
# 1. Переведем время в дата-фреймах из Unix-формата в формат даты.
# 2. Разделим пользователей на когорты по дню регистрации и определим количество пользователей (регистраций) в них. Для каждой авторизации пользователя определим, какой это по счету день использования приложения.
# 3. Для каждой когорты и дня использования рассчитаем количество пользователей, объединим с данными о размере когорты.
# 4. Рассчитаем retention. Отфильтруем данные по дате и количеству дней.
# 5. Сделаем когортную таблицу с данными retention по дате и дням.
#
# Затем объеденим все шаги внутри функции.

# %% [markdown]
# ##### 1. Перевод времени в дата-фреймах в дни

# %%
reg_data['reg_ts'] = pd.to_datetime(reg_data.reg_ts, unit='s').dt.date
auth_data['auth_ts'] = pd.to_datetime(auth_data.auth_ts, unit='s').dt.date

# %%
reg_data.head()
# Out:
#        reg_ts  uid
# 0  1998-11-18    1
# 1  1999-07-22    2
# 2  2000-01-13    3
# 3  2000-05-28    4
# 4  2000-09-16    5

# %%
auth_data.head()
# Out:
#       auth_ts  uid
# 0  1998-11-18    1
# 1  1999-07-22    2
# 2  1999-07-25    2
# 3  1999-07-31    2
# 4  1999-08-05    2

# %% [markdown]
# ###### 2. Разделение на когорты

# %%
# Определим количество регистраций в каждый из дней
reg_by_days = reg_data.groupby('reg_ts', as_index=False).uid.nunique() \
    .rename(columns={'uid': 'reg_count'})

# %%
# Объединим дата-фреймы по общему столбцу 'uid'
data = reg_data.merge(auth_data, on='uid', how='outer')

# %%
# Для каждой авторизации определим, какой это день использования приложения (день после регистрации)
data['use_day'] = (data.auth_ts - data.reg_ts).dt.days

# %%
data.head()
# Out:
#        reg_ts  uid     auth_ts  use_day
# 0  1998-11-18    1  1998-11-18        0
# 1  1999-07-22    2  1999-07-22        0
# 2  1999-07-22    2  1999-07-25        3
# 3  1999-07-22    2  1999-07-31        9
# 4  1999-07-22    2  1999-08-05       14

# %% [markdown]
# ##### 3. Ипользование приложения по дням и когортам

# %%
# Количество пользователей по дням использования и когортам
use_data = data.groupby(['reg_ts', 'use_day'], as_index=False).agg({'uid': 'nunique'})

# %%
# Добавим информацию о том, сколько всего регистраций было в когорте
use_data = use_data.merge(reg_by_days, on='reg_ts')

# %%
# Переименуем колонки
use_data = use_data.rename(columns={'reg_ts': 'cohort', 'uid': 'user_count'})

# %%
use_data.head()
# Out:
#        cohort  use_day  user_count  reg_count
# 0  1998-11-18        0           1          1
# 1  1999-07-22        0           1          1
# 2  1999-07-22        3           1          1
# 3  1999-07-22        9           1          1
# 4  1999-07-22       14           1          1

# %% [markdown]
# ##### 4. Расчет retention

# %%
use_data['retention'] = round((use_data.user_count / use_data.reg_count).mul(100), 2)

# %%
# Временной интервал
start_date = '2020-09-10'
end_date = '2020-09-23'

# Перевод строк в объект datetime
start_date = datetime.datetime.strptime(start_date, '%Y-%m-%d').date()
end_date = datetime.datetime.strptime(end_date, '%Y-%m-%d').date()


# Количество дней для расчета retention
n = 12

# %%
# Фильтрация данных по временному интервалу [start_date, end_date] и количеству дней
filtered_data = use_data.query('@start_date <= cohort <= @end_date and use_day <= @n')

# %%
filtered_data.head()
# Out:
#              cohort  use_day  user_count  reg_count  retention
# 2716123  2020-09-10        0        1609       1609     100.00
# 2716124  2020-09-10        1          33       1609       2.05
# 2716125  2020-09-10        2          69       1609       4.29
# 2716126  2020-09-10        3          77       1609       4.79
# 2716127  2020-09-10        4          68       1609       4.23

# %% [markdown]
# ##### 5. Когортная таблица

# %%
cohort_table = filtered_data.pivot(index='cohort', columns='use_day', values='retention')

# %%
ur_style = (cohort_table
            .style
            .set_caption('User retention by registration days')  # добавляем подпись
            .background_gradient(cmap='cividis')  # раскрашиваем ячейки по столбцам
            .highlight_null('white')  # делаем белый фон для значений NaN
            .format("{}%", na_rep=""))  # числа форматируем как проценты, NaN заменяем на пустоту
ur_style
# Out:
# <style  type="text/css" >
# #T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col12,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col11,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row3_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row3_col10,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row4_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row4_col9,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row5_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row5_col8,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row6_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row6_col7,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row7_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row7_col6,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col5,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row9_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row9_col4,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col3,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row11_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row11_col2,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row12_col0,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row12_col1,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row13_col0{
#             background-color:  #00224e;
#             color:  #f1f1f1;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col1{
#             background-color:  #bdae6c;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col2{
#             background-color:  #d3c05f;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col3,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col5,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col7,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col12,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col11,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col8,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col9,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col10,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row4_col6,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row5_col4,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row6_col5,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col2,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col1{
#             background-color:  #fee838;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col4{
#             background-color:  #4d556c;
#             color:  #f1f1f1;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col6{
#             background-color:  #baac6d;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col8,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col6{
#             background-color:  #d6c35d;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col9{
#             background-color:  #b7a96e;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col10{
#             background-color:  #fde334;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row0_col11,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col9{
#             background-color:  #c4b468;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col1{
#             background-color:  #4b546c;
#             color:  #f1f1f1;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col2{
#             background-color:  #a69c74;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col3{
#             background-color:  #e2cd54;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col4,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row7_col2{
#             background-color:  #d5c25e;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col5{
#             background-color:  #a19975;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col6{
#             background-color:  #e4ce53;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col7{
#             background-color:  #c7b767;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col8{
#             background-color:  #aba072;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row1_col10{
#             background-color:  #d9c55c;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col1,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col4{
#             background-color:  #a79d73;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col2{
#             background-color:  #888578;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col3,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row9_col3{
#             background-color:  #f8df3c;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col4{
#             background-color:  #727374;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col5,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col3{
#             background-color:  #c0b16a;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col7,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row3_col4{
#             background-color:  #9f9775;
#             color:  #000000;
#         }#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row2_col12,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row3_col11,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row3_col12,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row4_col10,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row4_col11,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row4_col12,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row5_col9,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row5_col10,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row5_col11,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row5_col12,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row6_col8,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row6_col9,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row6_col10,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row6_col11,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row6_col12,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row7_col7,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row7_col8,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row7_col9,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row7_col10,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row7_col11,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row7_col12,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col6,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col7,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col8,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col9,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col10,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col11,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row8_col12,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row9_col5,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row9_col6,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row9_col7,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row9_col8,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row9_col9,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row9_col10,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row9_col11,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row9_col12,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col4,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col5,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col6,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col7,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col8,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col9,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col10,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col11,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row10_col12,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row11_col3,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row11_col4,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row11_col5,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row11_col6,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row11_col7,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row11_col8,#T_2bd31240_18f5_11ef_bdbb_96000040dfb6row11_col9,#T_2bd31240_1

# %% [markdown]
# ### Написание функции

# %%
def retention(path_to_file_reg, path_to_file_auth, start_date, end_date, n):
    
    '''
    Функция retention рассчитывает retention игроков (по дням от даты регистрации игрока) 
    для заданного отчетного периода [start_date, end_date]. 
    
    Параметры:
    - path_to_file_reg (str) - путь к файлу с данными о времени регистрации;
    - path_to_file_auth (str) - путь к файлу данными о времени захода пользователей в игру;
    - start_date (str) - дата начала отчетного периода;
    - end_date (str) - дата окончания отчетного периода;
    - n (int) - количество дней для расчета retention.
    
    Возвращаемое значение:
    - Таблица со значениям retention по дням в процентах.
    '''
    
    # считывание данных
    reg_data = pd.read_csv(path_to_file_reg, sep=';')
    auth_data = pd.read_csv(path_to_file_auth, sep=';')
    
    # обработка входных данных
    start_date = datetime.datetime.strptime(start_date, '%Y-%m-%d').date()
    end_date = datetime.datetime.strptime(end_date, '%Y-%m-%d').date()
    
    # перевод времени из Unix-формата в дни
    reg_data['reg_ts'] = pd.to_datetime(reg_data.reg_ts, unit='s').dt.date
    auth_data['auth_ts'] = pd.to_datetime(auth_data.auth_ts, unit='s').dt.date
    
    # количество регистраций в каждый из дней
    reg_by_days = reg_data.groupby('reg_ts', as_index=False).uid.nunique() \
    .rename(columns={'uid': 'reg_count'})
    
    # разделение на когорты
    data = reg_data.merge(auth_data, on='uid', how='outer')
    data['use_day'] = (data.auth_ts - data.reg_ts).dt.days
    
    # использование приложения по дням и когортам
    use_data = data.groupby(['reg_ts', 'use_day'], as_index=False).agg({'uid': 'nunique'})
    use_data = use_data.merge(reg_by_days, on='reg_ts')
    use_data = use_data.rename(columns={'reg_ts': 'cohort', 'uid': 'user_count'})
        
    # расчет retention
    use_data['retention'] = round((use_data.user_count / use_data.reg_count).mul(100), 2)
    
    # фильтрация данных
    filtered_data = use_data.query('@start_date <= cohort <= @end_date and use_day <= @n')
    
    # когортная таблица
    cohort_table = filtered_data.pivot(index='cohort', columns='use_day', values='retention')
    
    ur_style = (cohort_table
            .style
            .set_caption('User retention by registration days')  # добавляем подпись
            .background_gradient(cmap='cividis')  # раскрашиваем ячейки по столбцам
            .highlight_null('white')  # делаем белый фон для значений NaN
            .format("{}%", na_rep=""))  # числа форматируем как проценты, NaN заменяем на пустоту

    return ur_style

# %%
print(retention.__doc__)
# Out:
#     Функция retention рассчитывает retention игроков (по дням от даты регистрации игрока)
#     для заданного отчетного периода [start_date, end_date].
#
#     Параметры:
#     - path_to_file_reg (str) - путь к файлу с данными о времени регистрации;
#     - path_to_file_auth (str) - путь к файлу данными о времени захода пользователей в игру;
#     - start_date (str) - дата начала отчетного периода;
#     - end_date (str) - дата окончания отчетного периода;
#     - n (int) - количество дней для расчета retention.
#
#     Возвращаемое значение:
#     - Таблица со значениям retention по дням в процентах.

# %%
retention(path_to_file_reg, path_to_file_auth, '2020-09-10', '2020-09-23', 12)
# Out:
# <style  type="text/css" >
# #T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col12,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col11,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row3_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row3_col10,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row4_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row4_col9,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row5_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row5_col8,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row6_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row6_col7,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row7_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row7_col6,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col5,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row9_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row9_col4,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col3,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row11_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row11_col2,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row12_col0,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row12_col1,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row13_col0{
#             background-color:  #00224e;
#             color:  #f1f1f1;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col1{
#             background-color:  #bdae6c;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col2{
#             background-color:  #d3c05f;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col3,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col5,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col7,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col12,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col11,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col8,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col9,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col10,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row4_col6,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row5_col4,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row6_col5,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col2,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col1{
#             background-color:  #fee838;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col4{
#             background-color:  #4d556c;
#             color:  #f1f1f1;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col6{
#             background-color:  #baac6d;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col8,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col6{
#             background-color:  #d6c35d;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col9{
#             background-color:  #b7a96e;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col10{
#             background-color:  #fde334;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row0_col11,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col9{
#             background-color:  #c4b468;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col1{
#             background-color:  #4b546c;
#             color:  #f1f1f1;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col2{
#             background-color:  #a69c74;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col3{
#             background-color:  #e2cd54;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col4,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row7_col2{
#             background-color:  #d5c25e;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col5{
#             background-color:  #a19975;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col6{
#             background-color:  #e4ce53;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col7{
#             background-color:  #c7b767;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col8{
#             background-color:  #aba072;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row1_col10{
#             background-color:  #d9c55c;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col1,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col4{
#             background-color:  #a79d73;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col2{
#             background-color:  #888578;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col3,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row9_col3{
#             background-color:  #f8df3c;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col4{
#             background-color:  #727374;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col5,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col3{
#             background-color:  #c0b16a;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col7,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row3_col4{
#             background-color:  #9f9775;
#             color:  #000000;
#         }#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row2_col12,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row3_col11,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row3_col12,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row4_col10,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row4_col11,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row4_col12,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row5_col9,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row5_col10,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row5_col11,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row5_col12,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row6_col8,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row6_col9,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row6_col10,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row6_col11,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row6_col12,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row7_col7,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row7_col8,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row7_col9,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row7_col10,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row7_col11,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row7_col12,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col6,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col7,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col8,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col9,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col10,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col11,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row8_col12,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row9_col5,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row9_col6,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row9_col7,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row9_col8,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row9_col9,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row9_col10,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row9_col11,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row9_col12,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col4,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col5,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col6,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col7,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col8,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col9,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col10,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col11,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row10_col12,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row11_col3,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row11_col4,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row11_col5,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row11_col6,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row11_col7,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row11_col8,#T_d4b10250_18f5_11ef_bdbb_96000040dfb6row11_col9,#T_d4b10250_1
