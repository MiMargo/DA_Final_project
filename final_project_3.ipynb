# %% [markdown]
# # Задание 3

# %% [markdown]
# ### В игре Plants & Gardens каждый месяц проводятся тематические события, ограниченные по времени. В них игроки могут получить уникальные предметы для сада и персонажей, дополнительные монеты или бонусы. Для получения награды требуется пройти ряд уровней за определенное время. С помощью каких метрик можно оценить результаты последнего прошедшего события?

# %% [markdown]
# Для того, чтобы оценить насколько событие привлекает пользователей, следует сравнить Retention во время события и в обычное время. Также пригодятся метрики "Среднее и общее время использования".

# %% [markdown]
# Более того следует посмотреть как событие влияет на "Средний чек" и "Конверсию".

# %% [markdown]
# ### Предположим, в другом событии мы усложнили механику событий так, что при каждой неудачной попытке выполнения уровня игрок будет откатываться на несколько уровней назад. Изменится ли набор метрик оценки результата? Если да, то как?

# %% [markdown]
# В таком случае, помимо имеющихся метрик, можно добавить метрику "Количество попыток". Слишком большое количество может отпугнуть пользователей и заставить их переждать событие.
